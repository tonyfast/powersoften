# %% [markdown]
# # The Number of Jupyter Kernels grabbed from github
#
#     https://github.com/jupyter/jupyter/wiki/Jupyter-kernels

# %%
    from renci.style import *; from pandas import *
# Out:
# <style>
#     iframe {
#         width: 100%;
#         min-height: 80vh;
#     }
#
#     body.rise-enabled .code_cell .input,
#     div.reveal .code_cell .input,
#     div.reveal .output_stderr,
#     div.rise-enabled .output_stderr {
#         display: none;
#     }
# </style>

# %%
    df = read_html('https://github.com/jupyter/jupyter/wiki/Jupyter-kernels')[0].set_index('Name')
# Out:
#     df = read_html('https://github.com/jupyter/jupyter/wiki/Jupyter-kernels')[0].set_index('Name')

# %%
    view = display(
        Markdown("# There are {} Jupyter kernels".format(len(df))),
        HTML(df.to_html()))
# Out:
#     view = display(
#         Markdown("# There are {} Jupyter kernels".format(len(df))),
#         HTML(df.to_html()))
# # There are 95 Jupyter kernels
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Jupyter/IPython Version</th>
#       <th>Language(s) Version</th>
#       <th>3rd party dependencies</th>
#       <th>Example Notebooks</th>
#       <th>Notes</th>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Coarray-Fortran</th>
#       <td>Jupyter 4.0</td>
#       <td>Fortran 2008/2015</td>
#       <td>GFortran &gt;= 7.1, OpenCoarrays, MPICH &gt;= 3.2</td>
#       <td>Demo, Binder demo</td>
#       <td>Docker image</td>
#     </tr>
#     <tr>
#       <th>sparkmagic</th>
#       <td>Jupyter &gt;=4.0</td>
# ...

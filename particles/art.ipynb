# %%
    # %reload_ext literacy

# %%
https://en.wikipedia.org/wiki/Pigment
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://en.wikipedia.org/wiki/Pigment"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

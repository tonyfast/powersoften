# %% [markdown]
# # [Media]()
#
# > Media is information that triggers the senses.  The best science happens in person

# %%
    from renci.style import *
    # %load_ext literacy.template
# Out:
# <style>
#     iframe {
#         width: 100%;
#         min-height: 80vh;
#         max-height: 1000px;
#     }
# </style>
# <style>
# body.rise-hack-active div.reveal .code_cell .input,
# body.rise-hack-active div.reveal .output_stderr {
#     display: none;
# }
# button.rise-hack:hover {
#     opacity: 0.7;
# }
# button.rise-hack {
#     font-weight: bold;
# }
# body.rise-hack-active button.rise-hack {
#     text-decoration: line-through;
# }
# </style>

# %%
## _Media_ & [Culture]()

We measure cultures based on their articles or remaining media.

    Import('.Moma');
# Out:
# ## _Media_ & [Culture]()
#
# We measure cultures based on their articles or remaining media.
#
#     Import('.Moma');

# %%
## _Media_ & [Design]()


* Bauhaus
* Powers of Ten
* Warhol Factory
* Beautiful Losers
* MIT Digital Media Lab
# Out:
# ## _Media_ & [Design]()
#
#
# * Bauhaus
# * Powers of Ten
# * Warhol Factory
# * Beautiful Losers
# * MIT Digital Media Lab

# %%
## _Media_ & [Systems]()
# Out:
# ## _Media_ & [Systems]()

# %%
http://cs-exhibitions.uni-klu.ac.at/index.php?id=187
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://cs-exhibitions.uni-klu.ac.at/index.php?id=187"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## _Media_ & [Materials]()
# Out:
# ## _Media_ & [Materials]()

# %%
https://www.britannica.com/topic/publishing/Newspaper-publishing
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.britannica.com/topic/publishing/Newspaper-publishing"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
http://www.oreilly.com/programming/free/
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://www.oreilly.com/programming/free/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
# [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook)
# Out:
# # [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook)

# %%
http://nbviewer.jupyter.org/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/00.00-Preface.ipynb#What-Is-Data-Science?
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://nbviewer.jupyter.org/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/00.00-Preface.ipynb#What-Is-Data-Science?"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## _Media_ & [Community]()
# Out:
# ## _Media_ & [Community]()

# %%
https://en.m.wikipedia.org/wiki/History_of_libraries
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://en.m.wikipedia.org/wiki/History_of_libraries"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
https://en.m.wikipedia.org/wiki/Library_of_Alexandria
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://en.m.wikipedia.org/wiki/Library_of_Alexandria"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
https://www.loc.gov/
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.loc.gov/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
http://www.pewinternet.org/2016/09/09/americans-attitudes-toward-public-libraries/
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://www.pewinternet.org/2016/09/09/americans-attitudes-toward-public-libraries/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
[](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5584989/ "2017")
# Out:
# [](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5584989/ "2017")
#         <iframe
#             width="600"
#             height="400"
#             src="https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5584989/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
### Styleguides


# [PEP8](https://www.python.org/dev/peps/pep-0008/)
# Out:
# ### Styleguides
#
#
# # [PEP8](https://www.python.org/dev/peps/pep-0008/)

# %%
    import this
# Out:
#     import this
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
https://en.m.wikipedia.org/wiki/The_Elements_of_Style
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://en.m.wikipedia.org/wiki/The_Elements_of_Style"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## [Mail Chimp Style Guide](https://github.com/mailchimp/content-style-guide)
# Out:
# ## [Mail Chimp Style Guide](https://github.com/mailchimp/content-style-guide)

# %%
http://speaking.io
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://speaking.io"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## _Media_ & [Media]()
# Out:
# ## _Media_ & [Media]()

# %%
http://nytlabs.com
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://nytlabs.com"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
https://cdn.rawgit.com/ceteri/oriole_jupyterday_atl/master/oriole_talk.slides.html
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://cdn.rawgit.com/ceteri/oriole_jupyterday_atl/master/oriole_talk.slides.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## [Carol Willing's JupyterCon 2017 Talk](https://www.slideshare.net/willingc/jupyter-and-music)
# Out:
# ## [Carol Willing's JupyterCon 2017 Talk](https://www.slideshare.net/willingc/jupyter-and-music)

# %%
http://www.slideshare.net/slideshow/embed_code/key/vFhp6iTEV5jIBW
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://www.slideshare.net/slideshow/embed_code/key/vFhp6iTEV5jIBW"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
https://github.com/tensorflow/magenta-demos/blob/master/jupyter-notebooks/Sketch_RNN.ipynb

# %%
http://nbviewer.jupyter.org/github/tensorflow/magenta-demos/blob/master/jupyter-notebooks/NSynth.ipynb#Part-2:-Timestretching
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="http://nbviewer.jupyter.org/github/tensorflow/magenta-demos/blob/master/jupyter-notebooks/NSynth.ipynb#Part-2:-Timestretching"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
## [LIGO Notebooks](https://losc.ligo.org/tutorials/)
# Out:
# ## [LIGO Notebooks](https://losc.ligo.org/tutorials/)
#         <iframe
#             width="600"
#             height="400"
#             src="https://losc.ligo.org/tutorials/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
<blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">The new NBA <a href="https://t.co/RkV6PkwXaD">pic.twitter.com/RkV6PkwXaD</a></p>&mdash; Mark Cuban (@mcuban) <a href="https://twitter.com/mcuban/status/846781342083923969?ref_src=twsrc%5Etfw">March 28, 2017</a></blockquote>
<script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
# Out:
# <blockquote class="twitter-tweet" data-lang="en"><p lang="en" dir="ltr">The new NBA <a href="https://t.co/RkV6PkwXaD">pic.twitter.com/RkV6PkwXaD</a></p>&mdash; Mark Cuban (@mcuban) <a href="https://twitter.com/mcuban/status/846781342083923969?ref_src=twsrc%5Etfw">March 28, 2017</a></blockquote>
# <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>

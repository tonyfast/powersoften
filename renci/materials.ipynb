# %% [markdown]
# # [Materials]()
#
# > It takes work to make change.  All our designs are bound by existing or future physics.

# %%
    # %load_ext literacy.template
    from style import *
# Out:
# <style>
#     iframe {
#         width: 100%;
#         min-height: 80vh;
#         max-height: 1000px;
#     }
# </style>
# <style>
# body.rise-hack-active.rise-enabled .code_cell .input,
# body.rise-hack-active.rise-enabled div.reveal .code_cell .input,
# body.rise-hack-active.rise-enabled div.reveal .output_stderr,
# body.rise-hack-active.rise-enabled div.rise-enabled .output_stderr {
#     display: none;
# }
# </style>

# %%
## _Materials_ & [Community]()

* Bauhaus
* Arts and Craft Movement
* Industrial Revolution
* Made to Wear clothing
# Out:
# ## _Materials_ & [Community]()
#
# * Bauhaus
# * Arts and Craft Movement
# * Industrial Revolution
# * Made to Wear clothing

# %%
## _Materials_ & [Media]()
# Out:
# ## _Materials_ & [Media]()

# %%
## _Materials_ & [Culture]()

Materials have had a massive impact on culture shifts
# Out:
# ## _Materials_ & [Culture]()
#
# Materials have had a massive impact on culture shifts

# %%
## _Materials_ & [Design]()
# Out:
# ## _Materials_ & [Design]()

# %%
## _Materials_ & [Systems]()

We live in the composite, ne the silicon age.  We know more now and knowing may not always be good.
# Out:
# ## _Materials_ & [Systems]()
#
# We live in the composite, ne the silicon age.  We know more now and knowing may not always be good.

# %%
    Import('.Bad News').show()
# Out:
#     Import('.Bad News').show()
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="984606ff-6024-45a2-b4cb-952820dfbc80">Loading BokehJS ...</span>
#     </div>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="1501769f-d262-4f65-8c63-9fd95527d01c"></div>
# </div>

# %%
### Good News
# Out:
# ### Good News

# %%
## _Materials_ & [Materials]()

How do we use historical information about materials to design new ones
Show pics of materials
# Out:
# ## _Materials_ & [Materials]()
#
# How do we use historical information about materials to design new ones
# Show pics of materials

# %%
https://zoomimgs.github.io/
# Out:
#         <iframe
#             width="600"
#             height="400"
#             src="https://zoomimgs.github.io/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
